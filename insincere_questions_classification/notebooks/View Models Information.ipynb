# %%
import pandas as pd

# %% [markdown]
# # View the models

# %%
pd.read_csv(r"../models/log_models.csv")
# Out:
#                  model_name  accuracy        f1  precision    recall  \
# 0       sgdclassifier_basic  0.826857  0.824648   0.839678  0.810145
# 1         sgdclassifier_adv  0.881430  0.881973   0.882389  0.881556
# 2           linearSVC_basic  0.880275  0.880764   0.881615  0.879915
# 3             linearSVC_adv  0.882193  0.882643   0.883732  0.881556
# 4  logisticregression_basic  0.882152  0.882278   0.885818  0.878765
# 5    logisticregression_adv  0.877862  0.877523   0.884474  0.870680
# 6        decisiontree_basic  0.781215  0.762099   0.840140  0.697324
# 7          decisiontree_adv  0.786495  0.780025   0.808760  0.753263
#
#     training_time               creation_time  training_size  \
# 0  0:00:05.987000  2019-03-07 21:58:24.453205         113134
# 1  0:00:06.677000  2019-03-07 21:59:29.257205         113134
# 2  0:00:02.829600  2019-03-07 22:01:15.559605         113134
# 3  0:00:28.634200  2019-03-07 22:02:49.625205         113134
# ...
